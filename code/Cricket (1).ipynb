# %% [markdown]
# # Libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA

# %% [markdown]
# #Read dataset

# %%
# !pip install sktime
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sktime in /usr/local/lib/python3.10/dist-packages (0.18.1)
# Requirement already satisfied: deprecated>=1.2.13 in /usr/local/lib/python3.10/dist-packages (from sktime) (1.2.14)
# Requirement already satisfied: numpy<1.25,>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from sktime) (1.22.4)
# Requirement already satisfied: pandas<2.0.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sktime) (1.5.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from sktime) (23.1)
# Requirement already satisfied: scikit-base<0.5.0 in /usr/local/lib/python3.10/dist-packages (from sktime) (0.4.5)
# Requirement already satisfied: scikit-learn<1.3.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from sktime) (1.2.2)
# Requirement already satisfied: scipy<2.0.0,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from sktime) (1.10.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated>=1.2.13->sktime) (1.14.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.0.0,>=1.1.0->sktime) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.0.0,>=1.1.0->sktime) (2022.7.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<1.3.0,>=0.24.0->sktime) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<1.3.0,>=0.24.0->sktime) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas<2.0.0,>=1.1.0->sktime) (1.16.0)

# %%
# !pip install --upgrade sktime
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sktime in /usr/local/lib/python3.10/dist-packages (0.18.1)
# Requirement already satisfied: deprecated>=1.2.13 in /usr/local/lib/python3.10/dist-packages (from sktime) (1.2.14)
# Requirement already satisfied: numpy<1.25,>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from sktime) (1.22.4)
# Requirement already satisfied: pandas<2.0.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sktime) (1.5.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from sktime) (23.1)
# Requirement already satisfied: scikit-base<0.5.0 in /usr/local/lib/python3.10/dist-packages (from sktime) (0.4.5)
# Requirement already satisfied: scikit-learn<1.3.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from sktime) (1.2.2)
# Requirement already satisfied: scipy<2.0.0,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from sktime) (1.10.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated>=1.2.13->sktime) (1.14.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.0.0,>=1.1.0->sktime) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.0.0,>=1.1.0->sktime) (2022.7.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<1.3.0,>=0.24.0->sktime) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<1.3.0,>=0.24.0->sktime) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas<2.0.0,>=1.1.0->sktime) (1.16.0)

# %%
# !pip install sktime[all_extras]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sktime[all_extras] in /usr/local/lib/python3.10/dist-packages (0.18.1)
# Requirement already satisfied: deprecated>=1.2.13 in /usr/local/lib/python3.10/dist-packages (from sktime[all_extras]) (1.2.14)
# Requirement already satisfied: numpy<1.25,>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from sktime[all_extras]) (1.22.4)
# Requirement already satisfied: pandas<2.0.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sktime[all_extras]) (1.5.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from sktime[all_extras]) (23.1)
# Requirement already satisfied: scikit-base<0.5.0 in /usr/local/lib/python3.10/dist-packages (from sktime[all_extras]) (0.4.5)
# Requirement already satisfied: scikit-learn<1.3.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from sktime[all_extras]) (1.2.2)
# Requirement already satisfied: scipy<2.0.0,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from sktime[all_extras]) (1.10.1)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from sktime[all_extras]) (23.1.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from sktime[all_extras]) (2.2.1)
# Requirement already satisfied: dash!=2.9.0 in /usr/local/lib/python3.10/dist-packages (from sktime[all_extras]) (2.10.1)
# Requirement already satisfied: dask in /usr/local/lib/python3.10/dist-packages (from sktime[all_extras]) (2022.12.1)
# Requirement already satisfied: dtw-python in /usr/local/lib/python3.10/dist-packages (from sktime[all_extras]) (1.3.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from sktime[all_extras]) (3.8.0)
# Requirement already satisfied: gluonts>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from sktime[all_extras]) (0.13.1)
# Requirement already satisfied: kotsu>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from sktime[all_extras]) (0.3.2)
# Requirement already satisfied: matplotlib>=3.3.2 in /usr/local/lib/python3.10/dist-packages (from sktime[all_extras]) (3.7.1)
# Requirement already satisfied: mne in /usr/local/lib/python3.10/dist-packages (from sktime[all_extras]) (1.4.0)
# Requirement already satisfied: pmdarima!=1.8.1,<3.0.0,>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from sktime[all_extras]) (2.0.3)
# Requirement already satisfied: prophet>=1.1 in /usr/local/lib/python3.10/dist-packages (from sktime[all_extras]) (1.1.3)
# Requirement already satisfied: scikit-posthocs>=0.6.5 in /usr/local/lib/python3.10/dist-packages (from sktime[all_extras]) (0.7.0)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from sktime[all_extras]) (0.12.2)
# Requirement already satisfied: statsmodels>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from sktime[all_extras]) (0.13.5)
# Requirement already satisfied: tbats>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sktime[all_extras]) (1.1.3)
# Requirement already satisfied: tsfresh>=0.17.0 in /usr/local/lib/python3.10/dist-packages (from sktime[all_extras]) (0.20.0)
# Requirement already satisfied: xarray in /usr/local/lib/python3.10/dist-packages (from sktime[all_extras]) (2022.12.0)
# Requirement already satisfied: seasonal in /usr/local/lib/python3.10/dist-packages (from sktime[all_extras]) (0.3.1)
# Requirement already satisfied: filterpy>=1.4.5 in /usr/local/lib/python3.10/dist-packages (from sktime[all_extras]) (1.4.5)
# Requirement already satisfied: hmmlearn>=0.2.7 in /usr/local/lib/python3.10/dist-packages (from sktime[all_extras]) (0.3.0)
# Requirement already satisfied: keras-self-attention in /usr/local/lib/python3.10/dist-packages (from sktime[all_extras]) (0.51.0)
# Requirement already satisfied: numba>=0.53 in /usr/local/lib/python3.10/dist-packages (from sktime[all_extras]) (0.56.4)
# Requirement already satisfied: pykalman>=0.9.5 in /usr/local/lib/python3.10/dist-packages (from sktime[all_extras]) (0.9.5)
# Requirement already satisfied: pyod>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from sktime[all_extras]) (1.0.9)
# Requirement already satisfied: statsforecast>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from sktime[all_extras]) (1.5.0)
# Requirement already satisfied: stumpy>=1.5.1 in /usr/local/lib/python3.10/dist-packages (from sktime[all_extras]) (1.11.1)
# Requirement already satisfied: tensorflow-probability<0.20.0 in /usr/local/lib/python3.10/dist-packages (from sktime[all_extras]) (0.19.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (from sktime[all_extras]) (2.12.0)
# Requirement already satisfied: tslearn>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from sktime[all_extras]) (0.5.3.2)
# Requirement already satisfied: Flask<=2.2.3,>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from dash!=2.9.0->sktime[all_extras]) (2.2.3)
# Requirement already satisfied: Werkzeug<=2.2.3 in /usr/local/lib/python3.10/dist-packages (from dash!=2.9.0->sktime[all_extras]) (2.2.3)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from dash!=2.9.0->sktime[all_extras]) (5.13.1)
# Requirement already satisfied: dash-html-components==2.0.0 in /usr/local/lib/python3.10/dist-packages (from dash!=2.9.0->sktime[all_extras]) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /usr/local/lib/python3.10/dist-packages (from dash!=2.9.0->sktime[all_extras]) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /usr/local/lib/python3.10/dist-packages (from dash!=2.9.0->sktime[all_extras]) (5.0.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated>=1.2.13->sktime[all_extras]) (1.14.1)
# Requirement already satisfied: pydantic~=1.7 in /usr/local/lib/python3.10/dist-packages (from gluonts>=0.9.0->sktime[all_extras]) (1.10.7)
# Requirement already satisfied: tqdm~=4.23 in /usr/local/lib/python3.10/dist-packages (from gluonts>=0.9.0->sktime[all_extras]) (4.65.0)
# Requirement already satisfied: toolz~=0.10 in /usr/local/lib/python3.10/dist-packages (from gluonts>=0.9.0->sktime[all_extras]) (0.12.0)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.10/dist-packages (from gluonts>=0.9.0->sktime[all_extras]) (4.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.2->sktime[all_extras]) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.2->sktime[all_extras]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.2->sktime[all_extras]) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.2->sktime[all_extras]) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.2->sktime[all_extras]) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.2->sktime[all_extras]) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.2->sktime[all_extras]) (2.8.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.53->sktime[all_extras]) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.53->sktime[all_extras]) (67.7.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.0.0,>=1.1.0->sktime[all_extras]) (2022.7.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->sktime[all_extras]) (1.2.0)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.10/dist-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->sktime[all_extras]) (0.29.34)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->sktime[all_extras]) (1.26.15)
# Requirement already satisfied: cmdstanpy>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from prophet>=1.1->sktime[all_extras]) (1.1.0)
# Requirement already satisfied: LunarCalendar>=0.0.9 in /usr/local/lib/python3.10/dist-packages (from prophet>=1.1->sktime[all_extras]) (0.0.9)
# Requirement already satisfied: convertdate>=2.1.2 in /usr/local/lib/python3.10/dist-packages (from prophet>=1.1->sktime[all_extras]) (2.4.0)
# Requirement already satisfied: holidays>=0.14.2 in /usr/local/lib/python3.10/dist-packages (from prophet>=1.1->sktime[all_extras]) (0.25)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from prophet>=1.1->sktime[all_extras]) (5.12.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from pyod>=0.8.0->sktime[all_extras]) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<1.3.0,>=0.24.0->sktime[all_extras]) (3.1.0)
# Requirement already satisfied: plotly-resampler in /usr/local/lib/python3.10/dist-packages (from statsforecast>=0.5.2->sktime[all_extras]) (0.8.3.2)
# Requirement already satisfied: fugue>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from statsforecast>=0.5.2->sktime[all_extras]) (0.8.4)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.12.1->sktime[all_extras]) (0.5.3)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from tensorflow-probability<0.20.0->sktime[all_extras]) (1.4.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from tensorflow-probability<0.20.0->sktime[all_extras]) (4.4.2)
# Requirement already satisfied: gast>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow-probability<0.20.0->sktime[all_extras]) (0.4.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.10/dist-packages (from tensorflow-probability<0.20.0->sktime[all_extras]) (0.1.8)
# Requirement already satisfied: requests>=2.9.1 in /usr/local/lib/python3.10/dist-packages (from tsfresh>=0.17.0->sktime[all_extras]) (2.27.1)
# Requirement already satisfied: distributed>=2.11.0 in /usr/local/lib/python3.10/dist-packages (from tsfresh>=0.17.0->sktime[all_extras]) (2022.12.1)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from dask->sktime[all_extras]) (8.1.3)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from dask->sktime[all_extras]) (2023.4.0)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.10/dist-packages (from dask->sktime[all_extras]) (1.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from dask->sktime[all_extras]) (6.0)
# Requirement already satisfied: pooch>=1.5 in /usr/local/lib/python3.10/dist-packages (from mne->sktime[all_extras]) (1.6.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from mne->sktime[all_extras]) (3.1.2)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->sktime[all_extras]) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->sktime[all_extras]) (23.3.3)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->sktime[all_extras]) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->sktime[all_extras]) (1.54.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow->sktime[all_extras]) (0.4.10)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->sktime[all_extras]) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->sktime[all_extras]) (16.0.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow->sktime[all_extras]) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->sktime[all_extras]) (3.20.3)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow->sktime[all_extras]) (2.12.2)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->sktime[all_extras]) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->sktime[all_extras]) (2.3.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->sktime[all_extras]) (0.32.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow->sktime[all_extras]) (0.40.0)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in /usr/local/lib/python3.10/dist-packages (from convertdate>=2.1.2->prophet>=1.1->sktime[all_extras]) (0.5.12)
# Requirement already satisfied: locket>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2.11.0->tsfresh>=0.17.0->sktime[all_extras]) (1.0.0)
# Requirement already satisfied: msgpack>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2.11.0->tsfresh>=0.17.0->sktime[all_extras]) (1.0.5)
# Requirement already satisfied: psutil>=5.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2.11.0->tsfresh>=0.17.0->sktime[all_extras]) (5.9.5)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /usr/local/lib/python3.10/dist-packages (from distributed>=2.11.0->tsfresh>=0.17.0->sktime[all_extras]) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2.11.0->tsfresh>=0.17.0->sktime[all_extras]) (1.7.0)
# Requirement already satisfied: tornado>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from distributed>=2.11.0->tsfresh>=0.17.0->sktime[all_extras]) (6.3.1)
# Requirement already satisfied: zict>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from distributed>=2.11.0->tsfresh>=0.17.0->sktime[all_extras]) (3.0.0)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from Flask<=2.2.3,>=1.0.4->dash!=2.9.0->sktime[all_extras]) (2.1.2)
# Requirement already satisfied: triad>=0.8.8 in /usr/local/lib/python3.10/dist-packages (from fugue>=0.8.1->statsforecast>=0.5.2->sktime[all_extras]) (0.8.8)
# Requirement already satisfied: adagio>=0.2.4 in /usr/local/lib/python3.10/dist-packages (from fugue>=0.8.1->statsforecast>=0.5.2->sktime[all_extras]) (0.2.4)
# Requirement already satisfied: qpd>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from fugue>=0.8.1->statsforecast>=0.5.2->sktime[all_extras]) (0.4.1)
# Requirement already satisfied: fugue-sql-antlr>=0.1.6 in /usr/local/lib/python3.10/dist-packages (from fugue>=0.8.1->statsforecast>=0.5.2->sktime[all_extras]) (0.1.6)
# Requirement already satisfied: pyarrow>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from fugue>=0.8.1->statsforecast>=0.5.2->sktime[all_extras]) (9.0.0)
# Requirement already satisfied: sqlglot in /usr/local/lib/python3.10/dist-packages (from fugue>=0.8.1->statsforecast>=0.5.2->sktime[all_extras]) (14.1.1)
# Requirement already satisfied: korean-lunar-calendar in /usr/local/lib/python3.10/dist-packages (from holidays>=0.14.2->prophet>=1.1->sktime[all_extras]) (0.3.1)
# Requirement already satisfied: ml-dtypes>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow->sktime[all_extras]) (0.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->mne->sktime[all_extras]) (2.1.2)
# Requirement already satisfied: ephem>=3.7.5.3 in /usr/local/lib/python3.10/dist-packages (from LunarCalendar>=0.0.9->prophet>=1.1->sktime[all_extras]) (4.1.4)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=5.0.0->dash!=2.9.0->sktime[all_extras]) (8.2.2)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.5->mne->sktime[all_extras]) (1.4.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.9.1->tsfresh>=0.17.0->sktime[all_extras]) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.9.1->tsfresh>=0.17.0->sktime[all_extras]) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.9.1->tsfresh>=0.17.0->sktime[all_extras]) (3.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->sktime[all_extras]) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->sktime[all_extras]) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->sktime[all_extras]) (3.4.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->sktime[all_extras]) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->sktime[all_extras]) (1.8.1)
# Requirement already satisfied: jupyter-dash>=0.4.2 in /usr/local/lib/python3.10/dist-packages (from plotly-resampler->statsforecast>=0.5.2->sktime[all_extras]) (0.4.2)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in /usr/local/lib/python3.10/dist-packages (from plotly-resampler->statsforecast>=0.5.2->sktime[all_extras]) (3.8.14)
# Requirement already satisfied: trace-updater>=0.0.8 in /usr/local/lib/python3.10/dist-packages (from plotly-resampler->statsforecast>=0.5.2->sktime[all_extras]) (0.0.9.1)
# Requirement already satisfied: antlr4-python3-runtime<4.12,>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from fugue-sql-antlr>=0.1.6->fugue>=0.8.1->statsforecast>=0.5.2->sktime[all_extras]) (4.11.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->sktime[all_extras]) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->sktime[all_extras]) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->sktime[all_extras]) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow->sktime[all_extras]) (1.3.1)
# Requirement already satisfied: retrying in /usr/local/lib/python3.10/dist-packages (from jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=0.5.2->sktime[all_extras]) (1.3.4)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=0.5.2->sktime[all_extras]) (7.34.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.10/dist-packages (from jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=0.5.2->sktime[all_extras]) (5.5.6)
# Requirement already satisfied: ansi2html in /usr/local/lib/python3.10/dist-packages (from jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=0.5.2->sktime[all_extras]) (1.8.0)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=0.5.2->sktime[all_extras]) (1.5.6)
# Requirement already satisfied: fs in /usr/local/lib/python3.10/dist-packages (from triad>=0.8.8->fugue>=0.8.1->statsforecast>=0.5.2->sktime[all_extras]) (2.4.16)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->sktime[all_extras]) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow->sktime[all_extras]) (3.2.2)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=0.5.2->sktime[all_extras]) (0.2.0)
# Requirement already satisfied: traitlets>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=0.5.2->sktime[all_extras]) (5.7.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=0.5.2->sktime[all_extras]) (6.1.12)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=0.5.2->sktime[all_extras]) (0.18.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=0.5.2->sktime[all_extras]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=0.5.2->sktime[all_extras]) (3.0.38)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=0.5.2->sktime[all_extras]) (2.14.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=0.5.2->sktime[all_extras]) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=0.5.2->sktime[all_extras]) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=0.5.2->sktime[all_extras]) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=0.5.2->sktime[all_extras]) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=0.5.2->sktime[all_extras]) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=0.5.2->sktime[all_extras]) (0.2.6)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-client->ipykernel->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=0.5.2->sktime[all_extras]) (5.3.0)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.10/dist-packages (from jupyter-client->ipykernel->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=0.5.2->sktime[all_extras]) (23.2.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.0->jupyter-client->ipykernel->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=0.5.2->sktime[all_extras]) (3.3.0)

# %% [markdown]
# ---
# This code snippet loads data for the Cricket dataset from a specified
# location using the load_from_tsfile_to_dataframe function from the sktime package. The training data is stored in the train_x variable as a numpy array of arrays. Similarly, the test data is stored in the test_x variable. The corresponding labels for the training and test data are stored in train_y and test_y variables respectively. The labels are converted to floats using the astype method. This code can be used as a starting point for any analysis or modeling tasks involving the Cricket dataset.
#
#
# ---

# %%
import os
import numpy as np
import pandas as pd
import sktime
from sktime.datasets import load_from_tsfile_to_dataframe

DATA_PATH = ""
TRAIN_FILE = "/content/drive/MyDrive/Multivariate_ts/Cricket/Cricket_TRAIN.ts"
TEST_FILE = "/content/drive/MyDrive/Multivariate_ts/Cricket/Cricket_TEST.ts"

def load_data():
    # Load train data
    train_x, train_y = load_from_tsfile_to_dataframe(os.path.join(DATA_PATH, TRAIN_FILE))
    train_x = np.array([np.array(row) for row in train_x["dim_0"]])

    # Load test data
    test_x, test_y = load_from_tsfile_to_dataframe(os.path.join(DATA_PATH, TEST_FILE))
    test_x = np.array([np.array(row) for row in test_x["dim_0"]])

    # Convert labels to integers
    train_y = train_y.astype(float)
    test_y = test_y.astype(float)

    return train_x, train_y, test_x, test_y

train_x, train_y, test_x, test_y = load_data()

# %% [markdown]
# # apply pca

# %% [markdown]
# The above code represents a data preprocessing pipeline for the cricket dataset.
#
#
# ---
#
#
# The preprocess_data() function takes in train_x and test_x as inputs, which are the training and testing feature sets respectively. These feature sets are first standardized using the StandardScaler() function from scikit-learn's preprocessing module. Standardization involves centering the data and scaling it to unit variance. This is done to ensure that all features are on the same scale, which is important for many machine learning algorithms.
#
#
# ---
#
#
# Next, Principal Component Analysis (PCA) is applied to the standardized data using the PCA() function from scikit-learn's decomposition module. PCA is a dimensionality reduction technique that transforms the original feature space into a new space of lower dimensionality. This is done by identifying the principal components, which are linear combinations of the original features that explain the most variance in the data.
#
# ---
#
# The n_components parameter specifies the number of principal components to keep. In this case, it is set to 5. Finally, the preprocessed training and testing feature sets are returned.
#
# ---
#
# Overall, this data preprocessing pipeline can help improve the performance of machine learning models on the cricket dataset by reducing the dimensionality of the feature space and scaling the data to a common range.

# %%
import os
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

def preprocess_data(train_x, test_x, n_components=5):
    # Scale the data
    scaler = StandardScaler()
    train_x = scaler.fit_transform(train_x)
    test_x = scaler.transform(test_x)

    # Apply PCA
    pca = PCA(n_components=n_components)
    train_x = pca.fit_transform(train_x)
    test_x = pca.transform(test_x)

    return train_x, test_x

# %%
 # Preprocess data using PCA
train_x, test_x = preprocess_data(train_x, test_x, n_components=5)

# %% [markdown]
# The code snippet you provided shows how to convert integer labels to one-hot encoded labels using the to_categorical function from Keras.
#
#
# ---
#
#
# One-hot encoding is a technique used to represent categorical variables as binary vectors. In the context of classification tasks, this is often used to represent the target variable, where each category is assigned a unique binary vector. Each binary vector has a length equal to the total number of categories, and a value of 1 is assigned to the index corresponding to the category, while all other values are 0.

# %%
# Convert labels to one-hot encoding
from keras.utils import to_categorical
train_y = train_y.astype(int)
test_y = test_y.astype(int)
train_y = to_categorical(train_y)
test_y = to_categorical(test_y)

# %% [markdown]
# ---
# This line of code calculates the number of classes in the dataset. It uses
# the shape attribute of the numpy array train_y to get the number of rows (which represents the number of instances in the dataset) and the number of columns (which represents the number of classes). Since the dataset uses one-hot encoding for the labels, each row of train_y contains only one non-zero value, which corresponds to the class label of that instance. Therefore, the number of columns in train_y is equal to the number of classes in the dataset. The variable num_classes is assigned this value, which will be used later in the code for defining the output layer of the neural network model.
#
#
# ---

# %%
num_classes = (train_y.shape[1])

# %% [markdown]
# #Resnet

# %% [markdown]
# This is a function that defines a ResNet model using Keras. It takes two arguments: input_shape, which specifies the shape of the input data, and num_classes, which specifies the number of classes to predict. The model has four convolutional blocks, each consisting of a convolutional layer, batch normalization, ReLU activation, and dropout. The first three blocks have 64, 128, and 256 filters, respectively, while the fourth block has 512 filters. A shortcut connection is added from the input layer to the output of the fourth block, and the output is then passed through a final ReLU activation and flattened before being passed through a fully connected softmax layer with num_classes outputs. The model is compiled with the Adam optimizer, categorical crossentropy loss, and accuracy metric. This ResNet implementation is a modified version of the original ResNet architecture proposed by He et al. (2015) and is commonly used for time series classification tasks.

# %%
from keras.models import Model
from keras.layers import Input, Conv1D, BatchNormalization, Activation, Add, Flatten, Dense, Dropout
from keras.regularizers import l2
def resnet(input_shape, num_classes):
    # Define the input layer
    input_layer = Input(shape=input_shape)

    # First convolutional block
    conv1 = Conv1D(filters=64, kernel_size=3, padding='same', kernel_regularizer=l2(1e-4))(input_layer)
    norm1 = BatchNormalization()(conv1)
    relu1 = Activation('relu')(norm1)
    drop1 = Dropout(0.2)(relu1)

    # Second convolutional block
    conv2 = Conv1D(filters=128, kernel_size=3, padding='same', kernel_regularizer=l2(1e-4))(drop1)
    norm2 = BatchNormalization()(conv2)
    relu2 = Activation('relu')(norm2)
    drop2 = Dropout(0.2)(relu2)

    # Third convolutional block
    conv3 = Conv1D(filters=256, kernel_size=3, padding='same', kernel_regularizer=l2(1e-4))(drop2)
    norm3 = BatchNormalization()(conv3)
    relu3 = Activation('relu')(norm3)
    drop3 = Dropout(0.2)(relu3)

    # Fourth convolutional block
    conv4 = Conv1D(filters=512, kernel_size=3, padding='same', kernel_regularizer=l2(1e-4))(drop3)
    norm4 = BatchNormalization()(conv4)
    relu4 = Activation('relu')(norm4)
    drop4 = Dropout(0.2)(relu4)

    # Add shortcut connection
    shortcut = Conv1D(filters=512, kernel_size=1, padding='same', kernel_regularizer=l2(1e-4))(input_layer)
    shortcut = BatchNormalization()(shortcut)
    output = Add()([drop4, shortcut])
    output = Activation('relu')(output)

    # Flatten and output
    flatten = Flatten()(output)
    dense = Dense(num_classes, activation='softmax')(flatten)

    # Create and compile the model
    model = Model(inputs=input_layer, outputs=dense)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    return model

# %%
import matplotlib.pyplot as plt

train_x = np.reshape(train_x, (train_x.shape[0], train_x.shape[1], 1))
test_x = np.reshape(test_x, (test_x.shape[0], test_x.shape[1], 1))

model = resnet(input_shape=(train_x.shape[1],1), num_classes=num_classes)
history = model.fit(train_x, train_y, validation_data=(test_x, test_y), epochs=100, batch_size=32)

# Evaluate the model on the test set
loss, accuracy = model.evaluate(test_x, test_y)
print(f"Test loss: {loss}")
print(f"Test accuracy: {accuracy}")

# Plot the accuracy graph
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot the loss graph
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# Out:
# Epoch 1/100
# 4/4 [==============================] - 17s 423ms/step - loss: 2.7723 - accuracy: 0.2407 - val_loss: 1.9083 - val_accuracy: 0.3750
# Epoch 2/100
# 4/4 [==============================] - 0s 30ms/step - loss: 1.9716 - accuracy: 0.4074 - val_loss: 1.8194 - val_accuracy: 0.3611
# Epoch 3/100
# 4/4 [==============================] - 0s 29ms/step - loss: 1.4069 - accuracy: 0.5370 - val_loss: 1.6595 - val_accuracy: 0.3472
# Epoch 4/100
# 4/4 [==============================] - 0s 68ms/step - loss: 1.2765 - accuracy: 0.6111 - val_loss: 1.5163 - val_accuracy: 0.4722
# Epoch 5/100
# 4/4 [==============================] - 0s 37ms/step - loss: 1.2201 - accuracy: 0.5741 - val_loss: 1.6381 - val_accuracy: 0.4722
# Epoch 6/100
# 4/4 [==============================] - 0s 30ms/step - loss: 1.0761 - accuracy: 0.6296 - val_loss: 1.6216 - val_accuracy: 0.4444
# Epoch 7/100
# 4/4 [==============================] - 0s 36ms/step - loss: 1.0707 - accuracy: 0.6296 - val_loss: 1.5969 - val_accuracy: 0.4444
# Epoch 8/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.9648 - accuracy: 0.6944 - val_loss: 1.6969 - val_accuracy: 0.4583
# Epoch 9/100
# 4/4 [==============================] - 0s 43ms/step - loss: 0.8486 - accuracy: 0.7037 - val_loss: 1.6825 - val_accuracy: 0.4306
# Epoch 10/100
# 4/4 [==============================] - 0s 48ms/step - loss: 0.8550 - accuracy: 0.6759 - val_loss: 1.5280 - val_accuracy: 0.4306
# Epoch 11/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.8253 - accuracy: 0.6759 - val_loss: 1.5177 - val_accuracy: 0.4028
# Epoch 12/100
# 4/4 [==============================] - 0s 41ms/step - loss: 0.6709 - accuracy: 0.7315 - val_loss: 1.6195 - val_accuracy: 0.4306
# Epoch 13/100
# 4/4 [==============================] - 0s 54ms/step - loss: 0.6961 - accuracy: 0.7500 - val_loss: 1.6571 - val_accuracy: 0.4167
# Epoch 14/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.5798 - accuracy: 0.8241 - val_loss: 1.5340 - val_accuracy: 0.4444
# Epoch 15/100
# 4/4 [==============================] - 0s 83ms/step - loss: 0.7847 - accuracy: 0.6481 - val_loss: 1.6091 - val_accuracy: 0.4306
# Epoch 16/100
# 4/4 [==============================] - 0s 56ms/step - loss: 0.6563 - accuracy: 0.7593 - val_loss: 1.8595 - val_accuracy: 0.3889
# Epoch 17/100
# 4/4 [==============================] - 0s 49ms/step - loss: 0.7127 - accuracy: 0.7870 - val_loss: 1.8730 - val_accuracy: 0.4167
# Epoch 18/100
# 4/4 [==============================] - 0s 49ms/step - loss: 0.7031 - accuracy: 0.7315 - val_loss: 1.7418 - val_accuracy: 0.4444
# Epoch 19/100
# 4/4 [==============================] - 0s 49ms/step - loss: 0.6178 - accuracy: 0.8056 - val_loss: 1.6002 - val_accuracy: 0.4583
# Epoch 20/100
# 4/4 [==============================] - 0s 50ms/step - loss: 0.6922 - accuracy: 0.7407 - val_loss: 1.4884 - val_accuracy: 0.4722
# Epoch 21/100
# 4/4 [==============================] - 0s 96ms/step - loss: 0.7457 - accuracy: 0.7407 - val_loss: 1.6275 - val_accuracy: 0.4722
# Epoch 22/100
# 4/4 [==============================] - 0s 75ms/step - loss: 0.5539 - accuracy: 0.7870 - val_loss: 1.7400 - val_accuracy: 0.4861
# Epoch 23/100
# 4/4 [==============================] - 0s 74ms/step - loss: 0.6076 - accuracy: 0.8333 - val_loss: 1.7165 - val_accuracy: 0.5000
# Epoch 24/100
# 4/4 [==============================] - 0s 78ms/step - loss: 0.5578 - accuracy: 0.7870 - val_loss: 1.7435 - val_accuracy: 0.4583
# Epoch 25/100
# 4/4 [==============================] - 0s 69ms/step - loss: 0.
100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.4014 - accuracy: 0.8981 - val_loss: 3.2435 - val_accuracy: 0.4444
# Epoch 86/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.2624 - accuracy: 0.9167 - val_loss: 3.2666 - val_accuracy: 0.4444
# Epoch 87/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.4010 - accuracy: 0.8796 - val_loss: 3.2365 - val_accuracy: 0.4583
# Epoch 88/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.2695 - accuracy: 0.9167 - val_loss: 3.2578 - val_accuracy: 0.4167
# Epoch 89/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3099 - accuracy: 0.8889 - val_loss: 3.3804 - val_accuracy: 0.3889
# Epoch 90/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.2425 - accuracy: 0.9444 - val_loss: 3.4590 - val_accuracy: 0.4167
# Epoch 91/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.3054 - accuracy: 0.9167 - val_loss: 3.5152 - val_accuracy: 0.4028
# Epoch 92/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.3319 - accuracy: 0.8981 - val_loss: 3.4408 - val_accuracy: 0.4306
# Epoch 93/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2876 - accuracy: 0.8889 - val_loss: 3.4146 - val_accuracy: 0.4306
# Epoch 94/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.2883 - accuracy: 0.9444 - val_loss: 3.4178 - val_accuracy: 0.4583
# Epoch 95/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.2375 - accuracy: 0.9352 - val_loss: 3.4770 - val_accuracy: 0.4306
# Epoch 96/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.3015 - accuracy: 0.9167 - val_loss: 3.6518 - val_accuracy: 0.4444
# Epoch 97/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.3006 - accuracy: 0.8981 - val_loss: 3.6480 - val_accuracy: 0.4167
# Epoch 98/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2922 - accuracy: 0.9167 - val_loss: 3.4689 - val_accuracy: 0.4583
# Epoch 99/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.2692 - accuracy: 0.9167 - val_loss: 3.5780 - val_accuracy: 0.4306
# Epoch 100/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2018 - accuracy: 0.9630 - val_loss: 3.5713 - val_accuracy: 0.4306
# 3/3 [==============================] - 0s 7ms/step - loss: 3.5713 - accuracy: 0.4306
# Test loss: 3.571303129196167
# Test accuracy: 0.4305555522441864

# %% [markdown]
# #Tapent

# %% [markdown]
# The tapnet function defines a neural network model using convolutional layers for feature extraction and a dense layer for classification. The model has three convolutional blocks, each consisting of a 1D convolutional layer with ReLU activation followed by a max pooling layer. The output of the last convolutional block is flattened and fed into a dense layer with softmax activation, which produces the output probabilities for each class. The model is compiled with Adam optimizer and categorical cross-entropy loss function. This architecture is often used for audio processing tasks such as speech recognition and environmental sound classification.

# %%
from keras.models import Model
from keras.layers import Input, Conv1D, MaxPooling1D, Flatten, Dense, concatenate, Dropout
def tapnet(input_shape, num_classes):
    # Define the input layer
    input_layer = Input(shape=input_shape)

    # First convolutional block
    conv1 = Conv1D(filters=64, kernel_size=3, activation='relu', padding='same')(input_layer)
    pool1 = MaxPooling1D(pool_size=2)(conv1)

    # Second convolutional block
    conv2 = Conv1D(filters=128, kernel_size=3, activation='relu', padding='same')(pool1)
    pool2 = MaxPooling1D(pool_size=2)(conv2)

    # Third convolutional block
    conv3 = Conv1D(filters=256, kernel_size=3, activation='relu', padding='same')(pool2)

    # Flatten the output from the convolutional layers
    flatten = Flatten()(conv3)

    # Define the output layer
    output_layer = Dense(units=num_classes, activation='softmax')(flatten)

    # Create the model
    model = Model(inputs=input_layer, outputs=output_layer)

    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    return model

# %%
model3 = tapnet(input_shape=(train_x.shape[1],1), num_classes=num_classes)
history3=model3.fit(train_x, train_y, validation_data=(test_x, test_y), epochs=100, batch_size=6)
# Evaluate the model on the test set
loss3, accuracy3 = model3.evaluate(test_x, test_y)
print(f"Test loss: {loss3}")
print(f"Test accuracy: {accuracy3*100}")
# Plot the accuracy graph
plt.plot(history3.history['accuracy'])
plt.plot(history3.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot the loss graph
plt.plot(history3.history['loss'])
plt.plot(history3.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# Out:
# Epoch 1/100
# 18/18 [==============================] - 2s 17ms/step - loss: 2.2540 - accuracy: 0.1944 - val_loss: 1.7579 - val_accuracy: 0.3333
# Epoch 2/100
# 18/18 [==============================] - 0s 7ms/step - loss: 1.5289 - accuracy: 0.4352 - val_loss: 1.5075 - val_accuracy: 0.4444
# Epoch 3/100
# 18/18 [==============================] - 0s 7ms/step - loss: 1.
100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0172 - accuracy: 1.0000 - val_loss: 3.9983 - val_accuracy: 0.4583
# Epoch 71/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0182 - accuracy: 0.9907 - val_loss: 3.9699 - val_accuracy: 0.4722
# Epoch 72/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0182 - accuracy: 0.9907 - val_loss: 4.1007 - val_accuracy: 0.4444
# Epoch 73/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0268 - accuracy: 0.9907 - val_loss: 3.9712 - val_accuracy: 0.4722
# Epoch 74/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0174 - accuracy: 1.0000 - val_loss: 4.1000 - val_accuracy: 0.4444
# Epoch 75/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0232 - accuracy: 0.9907 - val_loss: 4.0149 - val_accuracy: 0.4583
# Epoch 76/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0201 - accuracy: 1.0000 - val_loss: 4.1652 - val_accuracy: 0.4583
# Epoch 77/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0382 - accuracy: 0.9722 - val_loss: 4.0644 - val_accuracy: 0.4444
# Epoch 78/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0617 - accuracy: 0.9815 - val_loss: 4.1862 - val_accuracy: 0.4444
# Epoch 79/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0618 - accuracy: 0.9815 - val_loss: 4.0674 - val_accuracy: 0.4306
# Epoch 80/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0276 - accuracy: 0.9907 - val_loss: 4.1429 - val_accuracy: 0.4444
# Epoch 81/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0270 - accuracy: 0.9815 - val_loss: 4.1500 - val_accuracy: 0.4444
# Epoch 82/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0280 - accuracy: 1.0000 - val_loss: 4.1800 - val_accuracy: 0.4583
# Epoch 83/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0715 - accuracy: 0.9815 - val_loss: 4.0532 - val_accuracy: 0.4722
# Epoch 84/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0578 - accuracy: 0.9815 - val_loss: 4.3250 - val_accuracy: 0.3889
# Epoch 85/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0845 - accuracy: 0.9815 - val_loss: 3.9406 - val_accuracy: 0.4444
# Epoch 86/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0313 - accuracy: 0.9907 - val_loss: 4.3032 - val_accuracy: 0.4444
# Epoch 87/100
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0277 - accuracy: 0.9907 - val_loss: 4.0655 - val_accuracy: 0.4583
# Epoch 88/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0229 - accuracy: 0.9907 - val_loss: 4.1090 - val_accuracy: 0.4583
# Epoch 89/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.1031 - accuracy: 0.9722 - val_loss: 4.2057 - val_accuracy: 0.4306
# Epoch 90/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0586 - accuracy: 0.9630 - val_loss: 4.1822 - val_accuracy: 0.4444
# Epoch 91/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0312 - accuracy: 0.9907 - val_loss: 4.0510 - val_accuracy: 0.4444
# Epoch 92/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0176 - accuracy: 1.0000 - val_loss: 4.0888 - val_accuracy: 0.4444
# Epoch 93/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 4.2134 - val_accuracy: 0.4583
# Epoch 94/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 4.2605 - val_accuracy: 0.4583
# Epoch 95/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 4.2652 - val_accuracy: 0.4583
# Epoch 96/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 4.3419 - val_accuracy: 0.4583
# Epoch 97/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 4.3149 - val_accuracy: 0.4722
# Epoch 98/100
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 4.3862 - val_accuracy: 0.4583
# Epoch 99/100
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 4.3706 - val_accuracy: 0.4722
# Epoch 100/100
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 4.4305 - val_accuracy: 0.4583
# 3/3 [==============================] - 0s 25ms/step - loss: 4.4305 - accuracy: 0.4583
# Test loss: 4.430498123168945
# Test accuracy: 45.83333432674408

# %% [markdown]
# the model architecture in the code you provided is a variant of the CIF (Convolutional-Inception-FullyConnected) model, which combines convolutional and fully connected layers to achieve high performance in image classification tasks.
#
#
# ---
#
# This is a Convolutional Neural Network (CNN) model that has three convolutional blocks, followed by a GlobalAveragePooling1D layer and a dense output layer with a sigmoid activation function. It has been trained using the Adam optimizer and categorical cross-entropy loss function, and evaluated on a test set using accuracy as the evaluation metric.
#
# The model architecture is suitable for a 1D Convolutional model to classify time-series data. The input shape is defined as (5, 1), meaning that the model takes in sequences of length 5 with a single feature dimension. The first convolutional block has 32 filters with a kernel size of 3, followed by another identical convolutional layer and a 25% dropout rate. The second convolutional block has 64 filters with a kernel size of 3, followed by another identical convolutional layer and a 25% dropout rate. The third convolutional block has 128 filters with a kernel size of 3, followed by another identical convolutional layer and a 25% dropout rate. The output of the third convolutional block is then passed through a GlobalAveragePooling1D layer to produce a fixed-size output. Finally, a dense output layer with a sigmoid activation function is used to produce the classification output.

# %%
from keras.layers import Input, Conv1D, MaxPooling1D, GlobalAveragePooling1D, Dense

# Define the input shape
input_layer = Input(shape=(5, 1))

# Define the first convolutional block
conv1 = Conv1D(filters=32, kernel_size=3, padding='same', activation='relu')(input_layer)
conv1 = Conv1D(filters=32, kernel_size=3, padding='same', activation='relu')(conv1)
conv1 = Dropout(0.25)(conv1)

# Define the second convolutional block
conv2 = Conv1D(filters=64, kernel_size=3, padding='same', activation='relu')(conv1)
conv2 = Conv1D(filters=64, kernel_size=3, padding='same', activation='relu')(conv2)
conv2 = Dropout(0.25)(conv2)

# Define the third convolutional block
conv3 = Conv1D(filters=128, kernel_size=3, padding='same', activation='relu')(conv2)
conv3 = Conv1D(filters=128, kernel_size=3, padding='same', activation='relu')(conv3)
conv3 = Dropout(0.25)(conv3)

# Apply GlobalAveragePooling1D layer to the output of the third convolutional block
gap = GlobalAveragePooling1D()(conv3)

# Define the output layer and create the model
output_layer = Dense(units=num_classes, activation='sigmoid')(gap)
model2 = Model(inputs=input_layer, outputs=output_layer)

# Compile the model
model2.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history2 = model2.fit(train_x, train_y, validation_data=(test_x, test_y), epochs=100, batch_size=32)

# Evaluate the model on the test set
loss2, accuracy2 = model2.evaluate(test_x, test_y)
print(f"Test Loss: {loss2}, Test Accuracy: {accuracy2*100}")
# Out:
# Epoch 1/100
# 4/4 [==============================] - 3s 180ms/step - loss: 2.5670 - accuracy: 0.0463 - val_loss: 2.4289 - val_accuracy: 0.2083
# Epoch 2/100
# 4/4 [==============================] - 0s 16ms/step - loss: 2.4125 - accuracy: 0.1019 - val_loss: 2.3362 - val_accuracy: 0.3056
# Epoch 3/100
# 4/4 [==============================] - 0s 15ms/step - loss: 2.3315 - accuracy: 0.1667 - val_loss: 2.2141 - val_accuracy: 0.2500
# Epoch 4/100
# 4/4 [==============================] - 0s 15ms/step - loss: 2.2086 - accuracy: 0.2037 - val_loss: 2.0660 - val_accuracy: 0.2778
# Epoch 5/100
# 4/4 [==============================] - 0s 19ms/step - loss: 2.1603 - accuracy: 0.1481 - val_loss: 1.8887 - val_accuracy: 0.3056
# Epoch 6/100
# 4/4 [==============================] - 0s 15ms/step - loss: 1.9372 - accuracy: 0.2870 - val_loss: 1.7884 - val_accuracy: 0.3056
# Epoch 7/100
# 4/4 [==============================] - 0s 15ms/step - loss: 1.7880 - accuracy: 0.3333 - val_loss: 1.6716 - val_accuracy: 0.4028
# Epoch 8/100
# 4/4 [==============================] - 0s 16ms/step - loss: 1.7269 - accuracy: 0.2685 - val_loss: 1.5941 - val_accuracy: 0.3611
# Epoch 9/100
# 4/4 [==============================] - 0s 19ms/step - loss: 1.5346 - accuracy: 0.3889 - val_loss: 1.5756 - val_accuracy: 0.4444
# Epoch 10/100
# 4/4 [==============================] - 0s 15ms/step - loss: 1.5446 - accuracy: 0.3796 - val_loss: 1.5662 - val_accuracy: 0.4444
# Epoch 11/100
# 4/4 [==============================] - 0s 15ms/step - loss: 1.4787 - accuracy: 0.3889 - val_loss: 1.4199 - val_accuracy: 0.5000
# Epoch 12/100
# 4/4 [==============================] - 0s 18ms/step - loss: 1.4121 - accuracy: 0.5000 - val_loss: 1.3759 - val_accuracy: 0.4861
# Epoch 13/100
# 4/4 [==============================] - 0s 19ms/step - loss: 1.3192 - accuracy: 0.4815 - val_loss: 1.4111 - val_accuracy: 0.4167
# Epoch 14/100
# 4/4 [==============================] - 0s 15ms/step - loss: 1.3522 - accuracy: 0.5000 - val_loss: 1.4953 - val_accuracy: 0.4028
# Epoch 15/100
# 4/4 [==============================] - 0s 18ms/step - loss: 1.2280 - accuracy: 0.5000 - val_loss: 1.4425 - val_accuracy: 0.4861
# Epoch 16/100
# 4/4 [==============================] - 0s 15ms/step - loss: 1.3250 - accuracy: 0.4537 - val_loss: 1.4682 - val_accuracy: 0.4306
# Epoch 17/100
# 4/4 [==============================] - 0s 22ms/step - loss: 1.2079 - accuracy: 0.4815 - val_loss: 1.4356 - val_accuracy: 0.3889
# Epoch 18/100
# 4/4 [==============================] - 0s 16ms/step - loss: 1.1176 - accuracy: 0.5463 - val_loss: 1.4222 - val_accuracy: 0.4861
# Epoch 19/100
# 4/4 [==============================] - 0s 19ms/step - loss: 1.
100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.5188 - accuracy: 0.7593 - val_loss: 2.0614 - val_accuracy: 0.4583
# Epoch 81/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.4726 - accuracy: 0.8148 - val_loss: 2.0790 - val_accuracy: 0.4722
# Epoch 82/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.3934 - accuracy: 0.8333 - val_loss: 2.1446 - val_accuracy: 0.4722
# Epoch 83/100
# 4/4 [==============================] - 0s 27ms/step - loss: 0.5616 - accuracy: 0.7870 - val_loss: 2.1650 - val_accuracy: 0.4722
# Epoch 84/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.4896 - accuracy: 0.7778 - val_loss: 2.1285 - val_accuracy: 0.3611
# Epoch 85/100
# 4/4 [==============================] - 0s 29ms/step - loss: 0.4673 - accuracy: 0.7778 - val_loss: 2.2643 - val_accuracy: 0.3750
# Epoch 86/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.4735 - accuracy: 0.7685 - val_loss: 2.3418 - val_accuracy: 0.4722
# Epoch 87/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.4798 - accuracy: 0.8426 - val_loss: 2.3824 - val_accuracy: 0.4861
# Epoch 88/100
# 4/4 [==============================] - 0s 26ms/step - loss: 0.5061 - accuracy: 0.7500 - val_loss: 2.3774 - val_accuracy: 0.4028
# Epoch 89/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.4819 - accuracy: 0.7778 - val_loss: 2.4284 - val_accuracy: 0.3750
# Epoch 90/100
# 4/4 [==============================] - 0s 26ms/step - loss: 0.5340 - accuracy: 0.7407 - val_loss: 2.2045 - val_accuracy: 0.4167
# Epoch 91/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.5499 - accuracy: 0.8056 - val_loss: 2.1451 - val_accuracy: 0.5000
# Epoch 92/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.4246 - accuracy: 0.8148 - val_loss: 2.2642 - val_accuracy: 0.4444
# Epoch 93/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.5403 - accuracy: 0.7685 - val_loss: 2.2154 - val_accuracy: 0.4167
# Epoch 94/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.3145 - accuracy: 0.8796 - val_loss: 1.9710 - val_accuracy: 0.4444
# Epoch 95/100
# 4/4 [==============================] - 0s 26ms/step - loss: 0.4528 - accuracy: 0.8333 - val_loss: 2.0466 - val_accuracy: 0.4306
# Epoch 96/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.4848 - accuracy: 0.7870 - val_loss: 2.1936 - val_accuracy: 0.5139
# Epoch 97/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.3532 - accuracy: 0.8704 - val_loss: 2.4678 - val_accuracy: 0.4028
# Epoch 98/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.4756 - accuracy: 0.7778 - val_loss: 2.5011 - val_accuracy: 0.3889
# Epoch 99/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.4399 - accuracy: 0.8519 - val_loss: 2.2375 - val_accuracy: 0.4306
# Epoch 100/100
# 4/4 [==============================] - 0s 28ms/step - loss: 0.5477 - accuracy: 0.7870 - val_loss: 2.0956 - val_accuracy: 0.5000
# 3/3 [==============================] - 0s 7ms/step - loss: 2.0956 - accuracy: 0.5000
# Test Loss: 2.0955591201782227, Test Accuracy: 50.0

# %% [markdown]
# This code defines an Inception model for 1D convolutional neural networks in Keras. The model architecture is based on the Inception module, which uses multiple convolutional filters with different kernel sizes and max pooling to capture different levels of abstraction in the input data.
#
#
# ---
#
#
# The inception_module function defines a single Inception module, which takes an input tensor x and applies four different convolutional filters with different kernel sizes (1, 3, and 5) and max pooling. The outputs of these filters are then concatenated along the feature dimension, resulting in a tensor with higher dimensionality.
#
#
# ---
#
#
# The create_inception_model function uses the inception_module function to build a deep Inception model. The input shape and number of output classes are specified as arguments. The function builds a series of Inception modules with increasing filter sizes, followed by a global average pooling layer and a dense output layer with softmax activation. The model is compiled with categorical cross-entropy loss and the Adam optimizer.

# %%
# Plot the accuracy graph
plt.plot(history2.history['accuracy'])
plt.plot(history2.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot the loss graph
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
from tensorflow.keras import layers, models

def inception_module(x, filter_size):
    conv1 = layers.Conv1D(filter_size, kernel_size=1, padding='same', activation='relu')(x)
    conv3 = layers.Conv1D(filter_size, kernel_size=3, padding='same', activation='relu')(x)
    conv5 = layers.Conv1D(filter_size, kernel_size=5, padding='same', activation='relu')(x)
    max_pool = layers.MaxPooling1D(pool_size=3, strides=1, padding='same')(x)
    concat = layers.concatenate([conv1, conv3, conv5, max_pool], axis=-1)
    return concat

def create_inception_model(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)
    x = inputs
    x = inception_module(x, 32)
    x = inception_module(x, 64)
    x = inception_module(x, 128)
    x = inception_module(x, 256)
    x = layers.Flatten()(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    model = models.Model(inputs=inputs, outputs=outputs)
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %%
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
model4 = create_inception_model((5,1), num_classes=num_classes)
# Fit the model for 100 epochs
history4 = model4.fit(train_x, train_y, validation_data=(test_x, test_y), epochs=100, batch_size=32)

# Evaluate the model on the test set
loss4, accuracy4 = model4.evaluate(test_x, test_y)
print(f"Test loss: {loss4}")
print(f"Test accuracy: {accuracy4*100}")

# Plot the accuracy graph
plt.plot(history4.history['accuracy'])
plt.plot(history4.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot the loss graph
plt.plot(history4.history['loss'])
plt.plot(history4.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# Out:
# Epoch 1/100
# 4/4 [==============================] - 7s 365ms/step - loss: 11.4668 - accuracy: 0.0926 - val_loss: 24.2325 - val_accuracy: 0.2222
# Epoch 2/100
# 4/4 [==============================] - 0s 22ms/step - loss: 21.3965 - accuracy: 0.2685 - val_loss: 9.5060 - val_accuracy: 0.3333
# Epoch 3/100
# 4/4 [==============================] - 0s 18ms/step - loss: 6.8355 - accuracy: 0.3241 - val_loss: 5.4325 - val_accuracy: 0.2917
# Epoch 4/100
# 4/4 [==============================] - 0s 18ms/step - loss: 3.3688 - accuracy: 0.3426 - val_loss: 3.7265 - val_accuracy: 0.2361
# Epoch 5/100
# 4/4 [==============================] - 0s 21ms/step - loss: 1.9233 - accuracy: 0.4352 - val_loss: 2.0214 - val_accuracy: 0.4306
# Epoch 6/100
# 4/4 [==============================] - 0s 18ms/step - loss: 1.6536 - accuracy: 0.5370 - val_loss: 1.9214 - val_accuracy: 0.3889
# Epoch 7/100
# 4/4 [==============================] - 0s 20ms/step - loss: 1.0547 - accuracy: 0.6296 - val_loss: 2.1692 - val_accuracy: 0.4167
# Epoch 8/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.9535 - accuracy: 0.6667 - val_loss: 2.2069 - val_accuracy: 0.3750
# Epoch 9/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.8602 - accuracy: 0.6944 - val_loss: 2.0837 - val_accuracy: 0.4028
# Epoch 10/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.6822 - accuracy: 0.7130 - val_loss: 1.6817 - val_accuracy: 0.5000
# Epoch 11/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5782 - accuracy: 0.7778 - val_loss: 1.6365 - val_accuracy: 0.4583
# Epoch 12/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.6234 - accuracy: 0.7685 - val_loss: 1.6553 - val_accuracy: 0.4306
# Epoch 13/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.4913 - accuracy: 0.8056 - val_loss: 2.0294 - val_accuracy: 0.5000
# Epoch 14/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.5180 - accuracy: 0.7407 - val_loss: 2.2317 - val_accuracy: 0.4028
# Epoch 15/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.4296 - accuracy: 0.8148 - val_loss: 1.9858 - val_accuracy: 0.4583
# Epoch 16/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.4109 - accuracy: 0.8426 - val_loss: 1.8845 - val_accuracy: 0.5000
# Epoch 17/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.3361 - accuracy: 0.8704 - val_loss: 1.8567 - val_accuracy: 0.4167
# Epoch 18/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.3051 - accuracy: 0.9259 - val_loss: 1.9031 - val_accuracy: 0.4306
# Epoch 19/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.2567 - accuracy: 0.9167 - val_loss: 1.9399 - val_accuracy: 0.5000
# Epoch 20/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.2552 - accuracy: 0.9167 - val_loss: 2.0228 - val_accuracy: 0.4444
# Epoch 21/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.2071 - accuracy: 0.9630 - val_loss: 2.1992 - val_accuracy: 0.4167
# Epoch 22/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1979 - accuracy: 0.9630 - val_loss: 2.1711 - val_accuracy: 0.4306
# Epoch 23/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.1797 - accuracy: 0.9537 - val_loss: 2.1008 - val_accuracy: 0.4028
# Epoch 24/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.1633 - accuracy: 0.9907 - val_loss: 2.0953 - val_accuracy: 0.4583
# Epoch 25/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.1650 - accuracy: 0.9630 - val_loss: 2.2035 - val_accuracy: 0.4167
# Epoch 26/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.1346 - accuracy: 0.9907 - val_loss: 2.3423 - val_accuracy: 0.3889
# Epoch 27/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.1378 - accuracy: 0.9815 - val_loss: 2.3526 - val_accuracy: 0.4028
# Epoch 28/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1177 - accuracy: 0.9907 - val_loss: 2.3323 - val_accuracy: 0.4583
# Epoch 29/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1027 - accuracy: 0.9907 - val_loss: 2.3226 - val_accuracy: 0.4444
# Epoch 30/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.1031 - accuracy: 0.9907 - val_loss: 2.2955 - val_accuracy: 0.4444
# Epoch 31/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1022 - accuracy: 0.9722 - val_loss: 2.3500 - val_accuracy: 0.4722
# Epoch 32/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0850 - accuracy: 0.9907 - val_loss: 2.4988 - val_accuracy: 0.4306
# Epoch 33/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0807 - accuracy: 0.9907 - val_loss: 2.5473 - val_accuracy: 0.4167
# Epoch 34/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0822 - accuracy: 1.0000 - val_loss: 2.5013 - val_accuracy: 0.4444
# Epoch 35/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.1013 - accuracy: 0.9815 - val_loss: 2.5386 - val_accuracy: 0.4583
# Epoch 36/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.1207 - accuracy: 0.9815 - val_loss: 2.5441 - val_accuracy: 0.4861
# Epoch 37/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0743 - accuracy: 0.9722 - val_loss: 2.6275 - val_accuracy: 0.4722
# Epoch 38/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.1073 - accuracy: 0.9630 - val_loss: 2.7116 - val_accuracy: 0.4028
# Epoch 39/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0967 - accuracy: 0.9630 - val_loss: 2.6783 - val_accuracy: 0.4028
# Epoch 40/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0586 - accuracy: 0.9907 - val_loss: 2.6628 - val_accuracy: 0.4444
# Epoch 41/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0762 - accuracy: 0.9815 - val_loss: 2.6843 - val_accuracy: 0.4306
# Epoch 42/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0451 - accuracy: 1.0000 - val_loss: 2.7383 - val_accuracy: 0.4444
# Epoch 43/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0454 - accuracy: 1.0000 - val_loss: 2.7514 - val_accuracy: 0.4861
# Epoch 44/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0446 - accuracy: 0.9907 - val_loss: 2.7162 - val_accuracy: 0.4861
# Epoch 45/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0351 - accuracy: 1.0000 - val_loss: 2.7343 - val_accuracy: 0.4444
# Epoch 46/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0342 - accuracy: 1.0000 - val_loss: 2.7924 - val_accuracy: 0.4444
# Epoch 47/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0344 - accuracy: 0.9907 - val_loss: 2.8516 - val_accuracy: 0.4167
# Epoch 48/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0305 - accuracy: 1.0000 - val_loss: 2.8667 - val_accuracy: 0.4167
# Epoch 49/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0397 - accuracy: 0.9907 - val_loss: 2.8741 - val_accuracy: 0.4167
# Epoch 50/100
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0407 - accuracy: 0.9907 - val_loss: 2.9306 - val_accuracy: 0.4722
# Epoch 51/100
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0427 - accuracy: 0.9907 - val_loss: 2.8913 - val_accuracy: 0.4306
# Epoch 52/100
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0546 - accuracy: 0.9722 - val_loss: 2.9344 - val_accuracy: 0.4167
# Epoch 53/100
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0254 - accuracy: 1.0000 - val_loss: 3.0884 - val_accuracy: 0.4306
# Epoch 54/100
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0350 - accuracy: 0.9907 - val_loss: 3.0159 - val_accuracy: 0.4722
# Epoch 55/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0529 - accuracy: 0.9907 - val_loss: 2.9404 - val_accuracy: 0.4444
# Epoch 56/100
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0463 - accuracy: 0.9907 - val_loss: 3.2222 - val_accuracy: 0.4444
# Epoch 57/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0837 - accuracy: 0.9815 - val_loss: 3.0603 - val_accuracy: 0.4028
# Epoch 58/100
# 4/4 [==============================] - 0s 41ms/step - loss: 0.1056 - accuracy: 0.9537 - val_loss: 3.1420 - val_accuracy: 0.3750
# Epoch 59/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.1134 - accuracy: 0.9722 - val_loss: 3.1392 - val_accuracy: 0.4444
# Epoch 60/100
# 4/4 [==============================] - 0s 28ms/step - loss: 0.1731 - accuracy: 0.9630 - val_loss: 3.3127 - val_accuracy: 0.4306
# Epoch 61/100
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0989 - accuracy: 0.9537 - val_loss: 2.9731 - val_accuracy: 0.3889
# Epoch 62/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.1199 - accuracy: 0.9259 - val_loss: 2.8776 - val_accuracy: 0.4583
# Epoch 63/100
# 4/4 [==============================] - 0s 26ms/step - loss: 0.1503 - accuracy: 0.9630 - val_loss: 3.1318 - val_accuracy: 0.4583
# Epoch 64/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.1045 - accuracy: 0.9630 - val_loss: 3.1577 - val_accuracy: 0.4306
# Epoch 65/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.1045 - accuracy: 0.9537 - val_loss: 3.0508 - val_accuracy: 0.4306
# Epoch 66/100
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0655 - accuracy: 0.9722 - val_loss: 2.9297 - val_accuracy: 0.5139
# Epoch 67/100
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0397 - accuracy: 0.9907 - val_loss: 3.0145 - val_accuracy: 0.5139
# Epoch 68/100
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0403 - accuracy: 1.0000 - val_loss: 3.0300 - val_accuracy: 0.5139
# Epoch 69/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0196 - accuracy: 1.0000 - val_loss: 3.1531 - val_accuracy: 0.4583
# Epoch 70/100
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0306 - accuracy: 0.9907 - val_loss: 3.1885 - val_accuracy: 0.4444
# Epoch 71/100
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0167 - accuracy: 1.0000 - val_loss: 3.1987 - val_accuracy: 0.4444
# Epoch 72/100
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0197 - accuracy: 1.0000 - val_loss: 3.2138 - val_accuracy: 0.4583
# Epoch 73/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 3.2906 - val_accuracy: 0.5000
# Epoch 74/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0409 - accuracy: 0.9907 - val_loss: 3.3001 - val_accuracy: 0.4583
# Epoch 75/100
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0187 - accuracy: 0.9907 - val_loss: 3.2896 - val_accuracy: 0.4167
# Epoch 76/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0249 - accuracy: 0.9907 - val_loss: 3.3007 - val_accuracy: 0.4444
# Epoch 77/100
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 3.3467 - val_accuracy: 0.4306
# Epoch 78/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 3.3649 - val_accuracy: 0.4722
# Epoch 79/100
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0126 - accuracy: 1.0000 - val_loss: 3.3579 - val_accuracy: 0.4722
# Epoch 80/100
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 3.3505 - val_accuracy: 0.4583
# Epoch 81/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 3.3613 - val_accuracy: 0.4861
# Epoch 82/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 3.3972 - val_accuracy: 0.5000
# Epoch 83/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 3.4156 - val_accuracy: 0.4861
# Epoch 84/100
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 3.4065 - val_accuracy: 0.4861
# Epoch 85/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 3.4105 - val_accuracy: 0.4722
# Epoch 86/100
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 3.4156 - val_accuracy: 0.4861
# Epoch 87/100
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 3.4432 - val_accuracy: 0.5000
# Epoch 88/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 3.4744 - val_accuracy: 0.5000
# Epoch 89/100
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 3.4916 - val_accuracy: 0.5000
# Epoch 90/100
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 3.5000 - val_accuracy: 0.5000
# Epoch 91/100
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 3.5120 - val_accuracy: 0.5000
# Epoch 92/100
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 3.5206 - val_accuracy: 0.5000
# Epoch 93/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 3.5309 - val_accuracy: 0.5000
# Epoch 94/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 3.5534 - val_accuracy: 0.5000
# Epoch 95/100
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 3.5786 - val_accuracy: 0.5000
# Epoch 96/100
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 3.5948 - val_accuracy: 0.5000
# Epoch 97/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 3.6066 - val_accuracy: 0.4861
# Epoch 98/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 3.6223 - val_accuracy: 0.4861
# Epoch 99/100
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 3.6377 - val_accuracy: 0.5000
# Epoch 100/100
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 3.6492 - val_accuracy: 0.5000
# 3/3 [==============================] - 0s 10ms/step - loss: 3.6492 - accuracy: 0.5000
# Test loss: 3.6492300033569336
# Test accuracy: 50.0

# %% [markdown]
# # Rocket

# %% [markdown]
# The Rocket model is a simple yet effective 1D Convolutional Neural Network (CNN) architecture designed for time series classification tasks. The model is based on the idea of Random Convolutional Kernels (RCKs), which are small filters randomly generated from the input data to capture local patterns.
#
# The Rocket model consists of five convolutional blocks, each with a different number of filters and kernel size, and a final dense layer for classification. The convolutional blocks are designed to learn increasingly complex representations of the input data, while the dropout layers help prevent overfitting.
#
# The model uses batch normalization to normalize the activations between layers and to speed up the training process. Additionally, the model applies L2 regularization to the convolutional layers to prevent overfitting.
#
# Overall, the Rocket model is a simple, yet effective architecture for time series classification tasks, and it has been shown to achieve state-of-the-art performance on several benchmark datasets. Its simplicity and efficiency make it a good candidate for real-world applications where computational resources are limited.

# %%
from keras.models import Model
from keras.layers import Input, Conv1D, BatchNormalization, Activation, Add, Flatten, Dense, Dropout
from keras.regularizers import l2

def rocket(input_shape, num_classes):
    # Define the input layer
    input_layer = Input(shape=input_shape)

    # First convolutional block
    conv1 = Conv1D(filters=16, kernel_size=11, padding='same', kernel_regularizer=l2(1e-4))(input_layer)
    norm1 = BatchNormalization()(conv1)
    relu1 = Activation('relu')(norm1)
    drop1 = Dropout(0.2)(relu1)

    # Second convolutional block
    conv2 = Conv1D(filters=32, kernel_size=9, padding='same', kernel_regularizer=l2(1e-4))(drop1)
    norm2 = BatchNormalization()(conv2)
    relu2 = Activation('relu')(norm2)
    drop2 = Dropout(0.2)(relu2)

    # Third convolutional block
    conv3 = Conv1D(filters=64, kernel_size=7, padding='same', kernel_regularizer=l2(1e-4))(drop2)
    norm3 = BatchNormalization()(conv3)
    relu3 = Activation('relu')(norm3)
    drop3 = Dropout(0.2)(relu3)

    # Fourth convolutional block
    conv4 = Conv1D(filters=128, kernel_size=5, padding='same', kernel_regularizer=l2(1e-4))(drop3)
    norm4 = BatchNormalization()(conv4)
    relu4 = Activation('relu')(norm4)
    drop4 = Dropout(0.2)(relu4)

    # Fifth convolutional block
    conv5 = Conv1D(filters=256, kernel_size=3, padding='same', kernel_regularizer=l2(1e-4))(drop4)
    norm5 = BatchNormalization()(conv5)
    relu5 = Activation('relu')(norm5)
    drop5 = Dropout(0.2)(relu5)

    # Flatten and output
    flatten = Flatten()(drop5)
    dense = Dense(num_classes, activation='softmax')(flatten)

    # Create and compile the model
    model = Model(inputs=input_layer, outputs=dense)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    return model

# %%
import matplotlib.pyplot as plt

train_x = np.reshape(train_x, (train_x.shape[0], train_x.shape[1], 1))
test_x = np.reshape(test_x, (test_x.shape[0], test_x.shape[1], 1))

model5 = rocket(input_shape=(train_x.shape[1],1), num_classes=num_classes)
history5 = model5.fit(train_x, train_y, validation_data=(test_x, test_y), epochs=100, batch_size=16)

# Evaluate the model on the test set
loss5, accuracy5 = model5.evaluate(test_x, test_y)
print(f"Test loss: {loss5}")
print(f"Test accuracy: {accuracy5*100}")

# Plot the accuracy graph
plt.plot(history5.history['accuracy'])
plt.plot(history5.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot the loss graph
plt.plot(history5.history['loss'])
plt.plot(history5.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
# Out:
# Epoch 1/100
# 7/7 [==============================] - 6s
100
# 7/7 [==============================] - 0s 20ms/step - loss: 0.7203 - accuracy: 0.7130 - val_loss: 1.9252 - val_accuracy: 0.4028
# Epoch 65/100
# 7/7 [==============================] - 0s 20ms/step - loss: 0.8701 - accuracy: 0.6481 - val_loss: 2.0660 - val_accuracy: 0.3889
# Epoch 66/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.7749 - accuracy: 0.6574 - val_loss: 2.1721 - val_accuracy: 0.3611
# Epoch 67/100
# 7/7 [==============================] - 0s 24ms/step - loss: 0.7715 - accuracy: 0.7130 - val_loss: 2.1782 - val_accuracy: 0.3750
# Epoch 68/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.8331 - accuracy: 0.6574 - val_loss: 2.1449 - val_accuracy: 0.4167
# Epoch 69/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.8322 - accuracy: 0.7407 - val_loss: 2.1860 - val_accuracy: 0.4167
# Epoch 70/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.7118 - accuracy: 0.7130 - val_loss: 2.1169 - val_accuracy: 0.4306
# Epoch 71/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.7324 - accuracy: 0.7685 - val_loss: 2.0787 - val_accuracy: 0.4167
# Epoch 72/100
# 7/7 [==============================] - 0s 28ms/step - loss: 0.6413 - accuracy: 0.7870 - val_loss: 2.1472 - val_accuracy: 0.4306
# Epoch 73/100
# 7/7 [==============================] - 0s 24ms/step - loss: 0.7736 - accuracy: 0.7037 - val_loss: 2.1455 - val_accuracy: 0.4583
# Epoch 74/100
# 7/7 [==============================] - 0s 23ms/step - loss: 0.7962 - accuracy: 0.6944 - val_loss: 1.9837 - val_accuracy: 0.4167
# Epoch 75/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.7007 - accuracy: 0.7593 - val_loss: 2.0878 - val_accuracy: 0.4167
# Epoch 76/100
# 7/7 [==============================] - 0s 23ms/step - loss: 0.7410 - accuracy: 0.7315 - val_loss: 2.2814 - val_accuracy: 0.4167
# Epoch 77/100
# 7/7 [==============================] - 0s 20ms/step - loss: 0.6304 - accuracy: 0.7500 - val_loss: 2.1219 - val_accuracy: 0.3611
# Epoch 78/100
# 7/7 [==============================] - 0s 24ms/step - loss: 0.7792 - accuracy: 0.7222 - val_loss: 2.0319 - val_accuracy: 0.3889
# Epoch 79/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6618 - accuracy: 0.7500 - val_loss: 2.0742 - val_accuracy: 0.4028
# Epoch 80/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.7373 - accuracy: 0.7222 - val_loss: 2.3330 - val_accuracy: 0.4028
# Epoch 81/100
# 7/7 [==============================] - 0s 24ms/step - loss: 0.6450 - accuracy: 0.7870 - val_loss: 2.5086 - val_accuracy: 0.3889
# Epoch 82/100
# 7/7 [==============================] - 0s 23ms/step - loss: 0.8019 - accuracy: 0.7037 - val_loss: 2.2640 - val_accuracy: 0.4306
# Epoch 83/100
# 7/7 [==============================] - 0s 29ms/step - loss: 0.7017 - accuracy: 0.7315 - val_loss: 2.1252 - val_accuracy: 0.4722
# Epoch 84/100
# 7/7 [==============================] - 0s 24ms/step - loss: 0.7413 - accuracy: 0.7037 - val_loss: 2.3571 - val_accuracy: 0.4306
# Epoch 85/100
# 7/7 [==============================] - 0s 23ms/step - loss: 0.7732 - accuracy: 0.7130 - val_loss: 2.4202 - val_accuracy: 0.4444
# Epoch 86/100
# 7/7 [==============================] - 0s 29ms/step - loss: 0.7627 - accuracy: 0.6852 - val_loss: 2.3015 - val_accuracy: 0.4167
# Epoch 87/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.7109 - accuracy: 0.7593 - val_loss: 2.2819 - val_accuracy: 0.4306
# Epoch 88/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6972 - accuracy: 0.7407 - val_loss: 2.1841 - val_accuracy: 0.4583
# Epoch 89/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.6092 - accuracy: 0.7870 - val_loss: 2.2313 - val_accuracy: 0.4444
# Epoch 90/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.5342 - accuracy: 0.8056 - val_loss: 2.3585 - val_accuracy: 0.4444
# Epoch 91/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.5541 - accuracy: 0.7870 - val_loss: 2.3567 - val_accuracy: 0.4722
# Epoch 92/100
# 7/7 [==============================] - 0s 29ms/step - loss: 0.6096 - accuracy: 0.7685 - val_loss: 2.2320 - val_accuracy: 0.4583
# Epoch 93/100
# 7/7 [==============================] - 0s 24ms/step - loss: 0.6803 - accuracy: 0.7315 - val_loss: 2.1206 - val_accuracy: 0.4722
# Epoch 94/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.7554 - accuracy: 0.7222 - val_loss: 2.2628 - val_accuracy: 0.4722
# Epoch 95/100
# 7/7 [==============================] - 0s 29ms/step - loss: 0.6186 - accuracy: 0.7593 - val_loss: 2.4173 - val_accuracy: 0.4167
# Epoch 96/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6279 - accuracy: 0.8148 - val_loss: 2.4591 - val_accuracy: 0.4444
# Epoch 97/100
# 7/7 [==============================] - 0s 24ms/step - loss: 0.6561 - accuracy: 0.8056 - val_loss: 2.3698 - val_accuracy: 0.4306
# Epoch 98/100
# 7/7 [==============================] - 0s 74ms/step - loss: 0.6351 - accuracy: 0.7500 - val_loss: 2.3611 - val_accuracy: 0.4167
# Epoch 99/100
# 7/7 [==============================] - 0s 42ms/step - loss: 0.5781 - accuracy: 0.7500 - val_loss: 2.3854 - val_accuracy: 0.4167
# Epoch 100/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.5249 - accuracy: 0.8241 - val_loss: 2.3836 - val_accuracy: 0.4306
# 3/3 [==============================] - 0s 7ms/step - loss: 2.3836 - accuracy: 0.4306
# Test loss: 2.383561134338379
# Test accuracy: 43.05555522441864
# Text(0, 0.5, 'Loss')

# %% [markdown]
# # Accuracy

# %%
# Plot the loss graph for all models
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.plot(history3.history['loss'])
plt.plot(history3.history['val_loss'])
plt.plot(history4.history['loss'])
plt.plot(history4.history['val_loss'])
plt.plot(history5.history['loss'])
plt.plot(history5.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['ResNet train', 'ResNet test', 'CIF train', 'CIF test', 'TapNet train', 'TapNet test' ,'Inception Time train', 'Inception Time test','Rocket train','Roket test'], loc='upper right')
plt.show()

# %%
# Plot the val_accuracy graph for all models
plt.plot(history.history['val_accuracy'])
plt.plot(history2.history['val_accuracy'])
plt.plot(history3.history['val_accuracy'])
plt.plot(history4.history['val_accuracy'])
plt.plot(history5.history['val_accuracy'])
plt.title('Model accuracy during training ')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.legend(['ResNet', 'CIF', 'TapNet','Inception Time','Rocket'], loc='upper right')
plt.show()

# %%
# Plot the accuracy graph for all models
plt.plot(history.history['accuracy'])
plt.plot(history2.history['accuracy'])
plt.plot(history3.history['accuracy'])
plt.plot(history4.history['accuracy'])
plt.plot(history5.history['accuracy'])
plt.title('Model accuracy during testing')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.legend(['ResNet', 'CIF', 'TapNet','Inception Time','Rocket'], loc='upper right')
plt.show()

# %%
import json
import numpy as np

# Convert the history objects to serializable format
serializable_histories = {
    'history': history.history,
    'history2': history2.history,
    'history3': history3.history,
    'history4': history4.history,
    'history5': history5.history
}

# Convert numpy arrays to lists for serialization
for key, value in serializable_histories.items():
    for k, v in value.items():
        if isinstance(v, np.ndarray):
            serializable_histories[key][k] = v.tolist()

# Save the histories to a text file
with open('histories.txt', 'w') as file:
    json.dump(serializable_histories, file)

# %%
import json
import numpy as np

# Load the histories from the text file
with open('histories.txt', 'r') as file:
    serializable_histories = json.load(file)

# Convert lists back to numpy arrays
for key, value in serializable_histories.items():
    for k, v in value.items():
        if isinstance(v, list):
            serializable_histories[key][k] = np.array(v)

# Assign the loaded histories to individual variables
history = serializable_histories['history']
history2 = serializable_histories['history2']
history3 = serializable_histories['history3']
history4 = serializable_histories['history4']
history5 = serializable_histories['history5']

# %%
# Evaluate the models and store accuracy and loss values
losses = [loss, loss2, loss3, loss4, loss5]
accuracies = [accuracy, accuracy2, accuracy3, accuracy4, accuracy5]

# Model names
model_names = ['ResNet', 'CIF', 'TapNet', 'Inception Time', 'Rocket']

# Print the model names, accuracy, and loss
for model_name, loss_val, accuracy_val in zip(model_names, losses, accuracies):
    print(model_name)
    print("Accuracy:", accuracy_val*100)
    print("Loss:", loss_val)
    print()
# Out:
# ResNet
# Accuracy: 43.05555522441864
# Loss: 3.571303129196167
#
# CIF
# Accuracy: 50.0
# Loss: 2.0955591201782227
#
# TapNet
# Accuracy: 45.83333432674408
# Loss: 4.430498123168945
#
# Inception Time
# Accuracy: 50.0
# Loss: 3.6492300033569336
#
# Rocket
# Accuracy: 43.05555522441864
# Loss: 2.383561134338379
